# %% [markdown]
# # 00 — Colab Setup
#
# Install dependencies and (optionally) clone the repository.

# %%
# !pip -q install numpy scipy networkx matplotlib pyyaml

# %% [markdown]
# ## Option A (recommended): clone from GitHub after you push
#
# Edit the URL and run:

# %%
# !git clone https://github.com/YOUR_USERNAME/Loofah-SC-Percolation-Sim.git
# %cd Loofah-SC-Percolation-Sim

# %% [markdown]
# ## Import check

# %%
from loofah_sc_sim.geometry import generate_scaffold_graph
print('Import OK')
